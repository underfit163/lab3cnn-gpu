# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from tensorflow.keras.datasets import cifar100
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Dense, Flatten, Conv2D, MaxPooling2D, Activation, BatchNormalization
from tensorflow.keras import utils, optimizers, regularizers

# %% [markdown]
# Делим наш датасет на обучающую и тестовую выборку

# %%
(train_images, train_labels), (test_images, test_labels) = cifar100.load_data()

# %%
print('train_images: ', train_images.shape)
print('test_images: ', test_images.shape)
print('train_labels: ', train_labels.shape)
print('test_labels: ', test_labels.shape)
# Out:
# train_images:  (50000, 32, 32, 3)
# test_images:  (10000, 32, 32, 3)
# train_labels:  (50000, 1)
# test_labels:  (10000, 1)

# %% [markdown]
# Нормализация данных

# %%
train_labels = utils.to_categorical(train_labels, 100)
test_labels = utils.to_categorical(test_labels, 100)

train_images = train_images.astype('float32')
test_images = test_images.astype('float32')

train_images = train_images / 255
test_images = test_images / 255

# %% [markdown]
# создание модели нейронной сети

# %%
dropP = 0.2

model = Sequential()

model.add(Conv2D(128,(3,3),padding='same',input_shape=(32,32,3)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(128,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(dropP))

model.add(Conv2D(256,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(256,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(dropP))

model.add(Conv2D(256,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(256,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(dropP))

model.add(Flatten())
model.add(Dense(512, kernel_regularizer=regularizers.L2(1e-4)))
model.add(Activation('relu'))
model.add(Dropout(dropP))
model.add(BatchNormalization())
model.add(Dense(100,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 128)       3584
#
#  batch_normalization (BatchN  (None, 32, 32, 128)      512
#  ormalization)
#
#  activation (Activation)     (None, 32, 32, 128)       0
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 128)       147584
#
#  batch_normalization_1 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  activation_1 (Activation)   (None, 32, 32, 128)       0
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 128)      0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 256)       295168
#
#  batch_normalization_2 (Batc  (None, 16, 16, 256)      1024
#  hNormalization)
#
#  activation_2 (Activation)   (None, 16, 16, 256)       0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 256)       590080
#
#  batch_normalization_3 (Batc  (None, 16, 16, 256)      1024
#  hNormalization)
#
#  activation_3 (Activation)   (None, 16, 16, 256)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 256)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 256)         0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 256)         590080
#
#  batch_normalization_4 (Batc  (None, 8, 8, 256)        1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 8, 8, 256)         0
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 256)         590080
#
#  batch_normalization_5 (Batc  (None, 8, 8, 256)        1024
#  hNormalization)
#
#  activation_5 (Activation)   (None, 8, 8, 256)         0
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 256)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 256)         0
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 512)               2097664
#
#  activation_6 (Activation)   (None, 512)               0
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  batch_normalization_6 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_1 (Dense)             (None, 100)               51300
#
# =================================================================
# Total params: 4,372,708
# Trainable params: 4,369,124
# Non-trainable params: 3,584
# _________________________________________________________________

# %% [markdown]
# Компиляция модели

# %%
model.compile(optimizer=optimizers.Adagrad(learning_rate=0.05),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# Обучение модели

# %%
epochs = 50
batch_size = 64

hist = model.fit(train_images, train_labels, batch_size=batch_size, validation_data=(test_images, test_labels),
                 epochs=epochs)
# Out:
# Epoch 1/50
# 782/782 [==============================] - 23s 25ms/step - loss: 3.7133 - accuracy: 0.1588 - val_loss: 3.6041 - val_accuracy: 0.1866
# Epoch 2/50
# 782/782 [==============================] - 19s 25ms/step - loss: 2.8221 - accuracy: 0.3083 - val_loss: 3.0663 - val_accuracy: 0.2797
# Epoch 3/50
# 782/782 [==============================] - 19s 25ms/step - loss: 2.3751 - accuracy: 0.4024 - val_loss: 3.6555 - val_accuracy: 0.2446
# Epoch 4/50
# 782/782 [==============================] - 19s 25ms/step - loss: 2.1170 - accuracy: 0.4593 - val_loss: 2.6378 - val_accuracy: 0.3598
# Epoch 5/50
# 782/782 [==============================] - 19s 25ms/step - loss: 1.9171 - accuracy: 0.5056 - val_loss: 2.2918 - val_accuracy: 0.4323
# Epoch 6/50
# 782/782 [==============================] - 19s 25ms/step - loss: 1.7475 - accuracy: 0.5484 - val_loss: 2.2517 - val_accuracy: 0.4324
# Epoch 7/50
# 782/782 [==============================] - 19s 25ms/step - loss: 1.6123 - accuracy: 0.5780 - val_loss: 2.2241 - val_accuracy: 0.4528
# Epoch 8/50
# 782/782 [==============================] - 19s 25ms/step - loss: 1.4936 - accuracy: 0.6072 - val_loss: 2.4796 - val_accuracy: 0.4275
# Epoch 9/50
# 782/782 [==============================] - 20s 25ms/step - loss: 1.3853 - accuracy: 0.6356 - val_loss: 1.9543 - val_accuracy: 0.5201
# Epoch 10/50
# 782/782 [==============================] - 20s 25ms/step - loss: 1.2694 - accuracy: 0.6646 - val_loss: 1.8806 - val_accuracy: 0.5334
# Epoch 11/50
# 782/782 [==============================] - 20s 25ms/step - loss: 1.1772 - accuracy: 0.6875 - val_loss: 1.9638 - val_accuracy: 0.5149
# Epoch 12/50
# 782/782 [==============================] - 20s 25ms/step - loss: 1.1006 - accuracy: 0.7093 - val_loss: 2.0342 - val_accuracy: 0.5079
# Epoch 13/50
# 782/782 [==============================] - 20s 25ms/step - loss: 1.0107 - accuracy: 0.7330 - val_loss: 1.9374 - val_accuracy: 0.5364
# Epoch 14/50
# 782/782 [==============================] - 20s 25ms/step - loss: 0.9263 - accuracy: 0.7581 - val_loss: 2.1386 - val_accuracy: 0.5107
# Epoch 15/50
# 782/782 [==============================] - 20s 25ms/step - loss: 0.8506 - accuracy: 0.7794 - val_loss: 1.9022 - val_accuracy: 0.5581
# Epoch 16/50
# 782/782 [==============================] - 20s 25ms/step - loss: 0.7774 - accuracy: 0.7992 - val_loss: 1.7661 - val_accuracy: 0.5864
# Epoch 17/50
# 782/782 [==============================] - 20s 25ms/step - loss: 0.7136 - accuracy: 0.8207 - val_loss: 1.9229 - val_accuracy: 0.5675
# Epoch 18/50
# 782/782 [==============================] - 20s 25ms/step - loss: 0.6583 - accuracy: 0.8349 - val_loss: 1.8066 - val_accuracy: 0.5829
# Epoch 19/50
# 782/782 [==============================] - 20s 25ms/step - loss: 0.6090 - accuracy: 0.8519 - val_loss: 2.1533 - val_accuracy: 0.5456
# Epoch 20/50
# 782/782 [==============================] - 20s 25ms/step - loss: 0.5727 - accuracy: 0.8641 - val_loss: 1.9963 - val_accuracy: 0.5704
# Epoch 21/50
# 782/782 [==============================] - 20s 25ms/step - loss: 0.5289 - accuracy: 0.8795 - val_loss: 2.0291 - val_accuracy: 0.5764
# Epoch 22/50
# 782/782 [==============================] - 20s 25ms/step - loss: 0.4873 - accuracy: 0.8918 - val_loss: 2.0664 - val_accuracy: 0.5724
# Epoch 23/50
# 782/782 [==============================] - 20s 25ms/step - loss: 0.4689 - accuracy: 0.8979 - val_loss: 1.9263 - val_accuracy: 0.5952
# Epoch 24/50
# 782/782 [==============================] - 20s 26ms/step - loss: 0.4321 - accuracy: 0.9103 - val_loss: 2.1282 - val_accuracy: 0.5844
# Epoch 25/50
# 782/782 [==============================] - 20s 25ms/step - loss: 0.4204 - accuracy: 0.9120 - val_loss: 2.0153 - val_accuracy: 0.5856
# Epoch 26/50
# 782/782 [==============================] - 20s 25ms/step - loss: 0.3939 - accuracy: 0.9200 - val_loss: 1.8930 - val_accuracy: 0.6124
# Epoch 27/50
# 782/782 [==============================] - 20s 26ms/step - loss: 0.3739 - accuracy: 0.9281 - val_loss: 1.9173 - val_accuracy: 0.6082
# Epoch 28/50
# 782/782 [==============================] - 20s 25ms/step - loss: 0.3636 - accuracy: 0.9299 - val_loss: 2.2973 - val_accuracy: 0.5705
# Epoch 29/50
# 782/782 [==============================] - 20s 25ms/step - loss: 0.3452 - accuracy: 0.9367 - val_loss: 1.9541 - val_accuracy: 0.6050
# Epoch 30/50
# 782/782 [==============================] - 20s 26ms/step - loss: 0.3373 - accuracy: 0.9374 - val_loss: 2.1883 - val_accuracy: 0.5891
# Epoch 31/50
# 782/782 [==============================] - 20s 26ms/step - loss: 0.3285 - accuracy: 0.9399 - val_loss: 2.2214 - val_accuracy: 0.5788
# Epoch 32/50
# 782/782 [==============================] - 20s 26ms/step - loss: 0.3109 - accuracy: 0.9460 - val_loss: 2.0696 - val_accuracy: 0.6088
# Epoch 33/50
# 782/782 [==============================] - 20s 26ms/step - loss: 0.3090 - accuracy: 0.9472 - val_loss: 2.0837 - val_accuracy: 0.6060
# Epoch 34/50
# 782/782 [==============================] - 20s 26ms/step - loss: 0.2955 - accuracy: 0.9517 - val_loss: 2.0457 - val_accuracy: 0.6058
# Epoch 35/50
# 782/782 [==============================] - 20s 26ms/step - loss: 0.2813 - accuracy: 0.9546 - val_loss: 1.9730 - val_accuracy: 0.6133
# Epoch 36/50
# 782/782 [==============================] - 20s 26ms/step - loss: 0.2740 - accuracy: 0.9566 - val_loss: 2.0591 - val_accuracy: 0.6104
# Epoch 37/50
# 782/782 [==============================] - 20s 26ms/step - loss: 0.2737 - accuracy: 0.9556 - val_loss: 2.0647 - val_accuracy: 0.6092
# Epoch 38/50
# 782/782 [==============================] - 20s 26ms/step - loss: 0.2614 - accuracy: 0.9606 - val_loss: 2.0391 - val_accuracy: 0.6160
# Epoch 39/50
# 782/782 [==============================] - 20s 26ms/step - loss: 0.2568 - accuracy: 0.9616 - val_loss: 2.1700 - val_accuracy: 0.5863
# Epoch 40/50
# 782/782 [==============================] - 20s 26ms/step - loss: 0.2584 - accuracy: 0.9603 - val_loss: 2.1233 - val_accuracy: 0.6076
# Epoch 41/50
# 782/782 [==============================] - 20s 26ms/step - loss: 0.2507 - accuracy: 0.9619 - val_loss: 2.0263 - val_accuracy: 0.6192
# Epoch 42/50
# 782/782 [==============================] - 20s 26ms/step - loss: 0.2443 - accuracy: 0.9638 - val_loss: 2.0367 - val_accuracy: 0.6201
# Epoch 43/50
# 782/782 [==============================] - 20s 26ms/step - loss: 0.2371 - accuracy: 0.9651 - val_loss: 1.9870 - val_accuracy: 0.6296
# Epoch 44/50
# 782/782 [==============================] - 20s 26ms/step - loss: 0.2366 - accuracy: 0.9662 - val_loss: 2.1329 - val_accuracy: 0.6061
# Epoch 45/50
# 782/782 [==============================] - 20s 26ms/step - loss: 0.2366 - accuracy: 0.9648 - val_loss: 2.2075 - val_accuracy: 0.6009
# Epoch 46/50
# 782/782 [==============================] - 20s 26ms/step - loss: 0.2286 - accuracy: 0.9681 - val_loss: 2.0744 - val_accuracy: 0.6179
# Epoch 47/50
# 782/782 [==============================] - 20s 26ms/step - loss: 0.2247 - accuracy: 0.9684 - val_loss: 2.0345 - val_accuracy: 0.6254
# Epoch 48/50
# 782/782 [==============================] - 20s 26ms/step - loss: 0.2204 - accuracy: 0.9696 - val_loss: 2.0354 - val_accuracy: 0.6250
# Epoch 49/50
# 782/782 [==============================] - 20s 26ms/step - loss: 0.2139 - accuracy: 0.9715 - val_loss: 2.0696 - val_accuracy: 0.6208
# Epoch 50/50
# 782/782 [==============================] - 20s 26ms/step - loss: 0.2086 - accuracy: 0.9726 - val_loss: 2.1091 - val_accuracy: 0.6214

# %% [markdown]
# Проверка точности предсказания

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 2.1091 - accuracy: 0.6215

# %% [markdown]
# Графики

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
print(plt.show())
# Out:
# None
