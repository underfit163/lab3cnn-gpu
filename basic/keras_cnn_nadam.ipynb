# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from tensorflow.keras.datasets import cifar100
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras import utils, optimizers

# %% [markdown]
# Делим наш датасет на обучающую и тестовую выборку

# %%
(train_images, train_labels), (test_images, test_labels) = cifar100.load_data()

# %% [markdown]
# Нормализация данных

# %%
train_labels = utils.to_categorical(train_labels, 100)
test_labels = utils.to_categorical(test_labels, 100)

train_images = train_images.astype('float32')
test_images = test_images.astype('float32')

train_images = train_images / 255
test_images = test_images / 255

# %% [markdown]
# создание модели нейронной сети

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(MaxPooling2D(2, 2))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(2, 2))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(2, 2))

model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(100, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 64)          36928
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 2, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 64)                16448
#
#  dense_1 (Dense)             (None, 100)               6500
#
# =================================================================
# Total params: 79,268
# Trainable params: 79,268
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Компиляция модели

# %%
model.compile(optimizer=optimizers.Nadam(),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# Обучение модели

# %%
epochs = 50
batch_size = 64

hist = model.fit(train_images, train_labels, batch_size=batch_size, validation_data=(test_images, test_labels),
                 epochs=epochs)
# Out:
# Epoch 1/50
# 782/782 [==============================] - 6s 5ms/step - loss: 3.9760 - accuracy: 0.0943 - val_loss: 3.8518 - val_accuracy: 0.1163
# Epoch 2/50
# 782/782 [==============================] - 3s 4ms/step - loss: 3.3383 - accuracy: 0.2009 - val_loss: 3.2812 - val_accuracy: 0.2116
# Epoch 3/50
# 782/782 [==============================] - 4s 5ms/step - loss: 3.0431 - accuracy: 0.2536 - val_loss: 3.1461 - val_accuracy: 0.2399
# Epoch 4/50
# 782/782 [==============================] - 3s 4ms/step - loss: 2.8501 - accuracy: 0.2922 - val_loss: 2.9393 - val_accuracy: 0.2720
# Epoch 5/50
# 782/782 [==============================] - 3s 4ms/step - loss: 2.7016 - accuracy: 0.3175 - val_loss: 2.7522 - val_accuracy: 0.3103
# Epoch 6/50
# 782/782 [==============================] - 4s 5ms/step - loss: 2.5854 - accuracy: 0.3442 - val_loss: 2.7221 - val_accuracy: 0.3216
# Epoch 7/50
# 782/782 [==============================] - 4s 5ms/step - loss: 2.4868 - accuracy: 0.3629 - val_loss: 2.9766 - val_accuracy: 0.2719
# Epoch 8/50
# 782/782 [==============================] - 3s 4ms/step - loss: 2.4063 - accuracy: 0.3803 - val_loss: 2.6591 - val_accuracy: 0.3285
# Epoch 9/50
# 782/782 [==============================] - 4s 4ms/step - loss: 2.3342 - accuracy: 0.3953 - val_loss: 2.5648 - val_accuracy: 0.3509
# Epoch 10/50
# 782/782 [==============================] - 4s 5ms/step - loss: 2.2713 - accuracy: 0.4074 - val_loss: 2.5516 - val_accuracy: 0.3522
# Epoch 11/50
# 782/782 [==============================] - 4s 5ms/step - loss: 2.2152 - accuracy: 0.4177 - val_loss: 2.4953 - val_accuracy: 0.3688
# Epoch 12/50
# 782/782 [==============================] - 4s 5ms/step - loss: 2.1630 - accuracy: 0.4320 - val_loss: 2.4954 - val_accuracy: 0.3672
# Epoch 13/50
# 782/782 [==============================] - 4s 5ms/step - loss: 2.1207 - accuracy: 0.4398 - val_loss: 2.5159 - val_accuracy: 0.3719
# Epoch 14/50
# 782/782 [==============================] - 4s 5ms/step - loss: 2.0780 - accuracy: 0.4483 - val_loss: 2.4241 - val_accuracy: 0.3879
# Epoch 15/50
# 782/782 [==============================] - 4s 5ms/step - loss: 2.0378 - accuracy: 0.4591 - val_loss: 2.4283 - val_accuracy: 0.3828
# Epoch 16/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.9984 - accuracy: 0.4671 - val_loss: 2.4608 - val_accuracy: 0.3767
# Epoch 17/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.9618 - accuracy: 0.4758 - val_loss: 2.4273 - val_accuracy: 0.3912
# Epoch 18/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.9304 - accuracy: 0.4818 - val_loss: 2.4474 - val_accuracy: 0.3785
# Epoch 19/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.8982 - accuracy: 0.4878 - val_loss: 2.4042 - val_accuracy: 0.3941
# Epoch 20/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.8646 - accuracy: 0.4950 - val_loss: 2.4253 - val_accuracy: 0.3944
# Epoch 21/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.8406 - accuracy: 0.5001 - val_loss: 2.4641 - val_accuracy: 0.3790
# Epoch 22/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.8110 - accuracy: 0.5076 - val_loss: 2.4074 - val_accuracy: 0.3940
# Epoch 23/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.7897 - accuracy: 0.5115 - val_loss: 2.4436 - val_accuracy: 0.3961
# Epoch 24/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.7614 - accuracy: 0.5185 - val_loss: 2.4866 - val_accuracy: 0.3857
# Epoch 25/50
# 782/782 [==============================] - 4s 4ms/step - loss: 1.7401 - accuracy: 0.5262 - val_loss: 2.4595 - val_accuracy: 0.3929
# Epoch 26/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.7149 - accuracy: 0.5293 - val_loss: 2.4732 - val_accuracy: 0.3916
# Epoch 27/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.6933 - accuracy: 0.5329 - val_loss: 2.5361 - val_accuracy: 0.3821
# Epoch 28/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.6732 - accuracy: 0.5378 - val_loss: 2.6141 - val_accuracy: 0.3819
# Epoch 29/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.6535 - accuracy: 0.5438 - val_loss: 2.5110 - val_accuracy: 0.3906
# Epoch 30/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.6354 - accuracy: 0.5476 - val_loss: 2.5265 - val_accuracy: 0.3900
# Epoch 31/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.6178 - accuracy: 0.5506 - val_loss: 2.5835 - val_accuracy: 0.3807
# Epoch 32/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.6002 - accuracy: 0.5522 - val_loss: 2.6315 - val_accuracy: 0.3782
# Epoch 33/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.5863 - accuracy: 0.5563 - val_loss: 2.5284 - val_accuracy: 0.3921
# Epoch 34/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.5658 - accuracy: 0.5634 - val_loss: 2.5627 - val_accuracy: 0.3936
# Epoch 35/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.5529 - accuracy: 0.5640 - val_loss: 2.6126 - val_accuracy: 0.3866
# Epoch 36/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.5390 - accuracy: 0.5676 - val_loss: 2.6363 - val_accuracy: 0.3791
# Epoch 37/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.5187 - accuracy: 0.5735 - val_loss: 2.7237 - val_accuracy: 0.3780
# Epoch 38/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.5057 - accuracy: 0.5761 - val_loss: 2.7480 - val_accuracy: 0.3848
# Epoch 39/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.4901 - accuracy: 0.5770 - val_loss: 2.7077 - val_accuracy: 0.3802
# Epoch 40/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.4802 - accuracy: 0.5831 - val_loss: 2.7068 - val_accuracy: 0.3807
# Epoch 41/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.4633 - accuracy: 0.5861 - val_loss: 2.7153 - val_accuracy: 0.3835
# Epoch 42/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.4465 - accuracy: 0.5889 - val_loss: 2.7293 - val_accuracy: 0.3791
# Epoch 43/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.4311 - accuracy: 0.5926 - val_loss: 2.7483 - val_accuracy: 0.3772
# Epoch 44/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.4234 - accuracy: 0.5932 - val_loss: 2.7371 - val_accuracy: 0.3847
# Epoch 45/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.4088 - accuracy: 0.5978 - val_loss: 2.7911 - val_accuracy: 0.3748
# Epoch 46/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.3934 - accuracy: 0.6030 - val_loss: 2.7856 - val_accuracy: 0.3826
# Epoch 47/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.3832 - accuracy: 0.6057 - val_loss: 2.8055 - val_accuracy: 0.3809
# Epoch 48/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.3742 - accuracy: 0.6075 - val_loss: 2.9285 - val_accuracy: 0.3672
# Epoch 49/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.3640 - accuracy: 0.6086 - val_loss: 2.8286 - val_accuracy: 0.3779
# Epoch 50/50
# 782/782 [==============================] - 4s 5ms/step - loss: 1.3502 - accuracy: 0.6124 - val_loss: 2.8901 - val_accuracy: 0.3732

# %% [markdown]
# Проверка точности предсказания

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 2.8900 - accuracy: 0.3732

# %% [markdown]
# Графики

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
print(plt.show())
# Out:
# None
