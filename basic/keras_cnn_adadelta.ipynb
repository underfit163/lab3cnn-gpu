# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from tensorflow.keras.datasets import cifar100
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras import utils, optimizers

# %% [markdown]
# Делим наш датасет на обучающую и тестовую выборку

# %%
(train_images, train_labels), (test_images, test_labels) = cifar100.load_data()

# %%
print('train_images: ', train_images.shape)
print('test_images: ', test_images.shape)
print('train_labels: ', train_labels.shape)
print('test_labels: ', test_labels.shape)
# Out:
# train_images:  (50000, 32, 32, 3)
# test_images:  (10000, 32, 32, 3)
# train_labels:  (50000, 1)
# test_labels:  (10000, 1)

# %% [markdown]
# Нормализация данных

# %%
train_labels = utils.to_categorical(train_labels, 100)
test_labels = utils.to_categorical(test_labels, 100)

train_images = train_images.astype('float32')
test_images = test_images.astype('float32')

train_images = train_images / 255
test_images = test_images / 255

# %% [markdown]
# создание модели нейронной сети

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(MaxPooling2D(2, 2))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(2, 2))

model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(2, 2))

model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(100, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 64)          36928
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 2, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 64)                16448
#
#  dense_1 (Dense)             (None, 100)               6500
#
# =================================================================
# Total params: 79,268
# Trainable params: 79,268
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Компиляция модели

# %%
model.compile(optimizer=optimizers.Adadelta(learning_rate=0.15),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# Обучение модели

# %%
epochs = 50
batch_size = 64

hist = model.fit(train_images, train_labels, batch_size=batch_size, validation_data=(test_images, test_labels),
                 epochs=epochs)
# Out:
# Epoch 1/50
# 782/782 [==============================] - 5s 4ms/step - loss: 4.4497 - accuracy: 0.0273 - val_loss: 4.3147 - val_accuracy: 0.0390
# Epoch 2/50
# 782/782 [==============================] - 2s 3ms/step - loss: 4.1877 - accuracy: 0.0577 - val_loss: 4.1501 - val_accuracy: 0.0693
# Epoch 3/50
# 782/782 [==============================] - 2s 3ms/step - loss: 4.0331 - accuracy: 0.0871 - val_loss: 3.9893 - val_accuracy: 0.1012
# Epoch 4/50
# 782/782 [==============================] - 2s 3ms/step - loss: 3.8874 - accuracy: 0.1136 - val_loss: 3.8898 - val_accuracy: 0.1132
# Epoch 5/50
# 782/782 [==============================] - 2s 3ms/step - loss: 3.7633 - accuracy: 0.1348 - val_loss: 3.7478 - val_accuracy: 0.1341
# Epoch 6/50
# 782/782 [==============================] - 2s 3ms/step - loss: 3.6626 - accuracy: 0.1504 - val_loss: 3.6470 - val_accuracy: 0.1548
# Epoch 7/50
# 782/782 [==============================] - 2s 3ms/step - loss: 3.5742 - accuracy: 0.1642 - val_loss: 3.6276 - val_accuracy: 0.1563
# Epoch 8/50
# 782/782 [==============================] - 2s 3ms/step - loss: 3.4980 - accuracy: 0.1750 - val_loss: 3.6229 - val_accuracy: 0.1514
# Epoch 9/50
# 782/782 [==============================] - 2s 3ms/step - loss: 3.4290 - accuracy: 0.1888 - val_loss: 3.6783 - val_accuracy: 0.1482
# Epoch 10/50
# 782/782 [==============================] - 2s 3ms/step - loss: 3.3660 - accuracy: 0.1999 - val_loss: 3.4792 - val_accuracy: 0.1779
# Epoch 11/50
# 782/782 [==============================] - 2s 3ms/step - loss: 3.3060 - accuracy: 0.2109 - val_loss: 3.3696 - val_accuracy: 0.2008
# Epoch 12/50
# 782/782 [==============================] - 2s 3ms/step - loss: 3.2522 - accuracy: 0.2196 - val_loss: 3.3065 - val_accuracy: 0.2112
# Epoch 13/50
# 782/782 [==============================] - 2s 3ms/step - loss: 3.2039 - accuracy: 0.2283 - val_loss: 3.3338 - val_accuracy: 0.2057
# Epoch 14/50
# 782/782 [==============================] - 2s 3ms/step - loss: 3.1589 - accuracy: 0.2357 - val_loss: 3.2527 - val_accuracy: 0.2228
# Epoch 15/50
# 782/782 [==============================] - 2s 3ms/step - loss: 3.1179 - accuracy: 0.2439 - val_loss: 3.1967 - val_accuracy: 0.2320
# Epoch 16/50
# 782/782 [==============================] - 2s 3ms/step - loss: 3.0778 - accuracy: 0.2507 - val_loss: 3.1639 - val_accuracy: 0.2395
# Epoch 17/50
# 782/782 [==============================] - 2s 3ms/step - loss: 3.0407 - accuracy: 0.2601 - val_loss: 3.1647 - val_accuracy: 0.2393
# Epoch 18/50
# 782/782 [==============================] - 2s 3ms/step - loss: 3.0068 - accuracy: 0.2661 - val_loss: 3.1135 - val_accuracy: 0.2530
# Epoch 19/50
# 782/782 [==============================] - 2s 3ms/step - loss: 2.9748 - accuracy: 0.2717 - val_loss: 3.1477 - val_accuracy: 0.2415
# Epoch 20/50
# 782/782 [==============================] - 2s 3ms/step - loss: 2.9430 - accuracy: 0.2786 - val_loss: 3.0855 - val_accuracy: 0.2555
# Epoch 21/50
# 782/782 [==============================] - 2s 3ms/step - loss: 2.9137 - accuracy: 0.2858 - val_loss: 3.0653 - val_accuracy: 0.2612
# Epoch 22/50
# 782/782 [==============================] - 2s 3ms/step - loss: 2.8854 - accuracy: 0.2905 - val_loss: 3.0223 - val_accuracy: 0.2640
# Epoch 23/50
# 782/782 [==============================] - 2s 3ms/step - loss: 2.8598 - accuracy: 0.2958 - val_loss: 2.9774 - val_accuracy: 0.2741
# Epoch 24/50
# 782/782 [==============================] - 2s 3ms/step - loss: 2.8331 - accuracy: 0.3020 - val_loss: 3.0378 - val_accuracy: 0.2652
# Epoch 25/50
# 782/782 [==============================] - 2s 3ms/step - loss: 2.8081 - accuracy: 0.3064 - val_loss: 3.0499 - val_accuracy: 0.2687
# Epoch 26/50
# 782/782 [==============================] - 3s 3ms/step - loss: 2.7835 - accuracy: 0.3105 - val_loss: 2.9334 - val_accuracy: 0.2874
# Epoch 27/50
# 782/782 [==============================] - 2s 3ms/step - loss: 2.7610 - accuracy: 0.3151 - val_loss: 3.0873 - val_accuracy: 0.2541
# Epoch 28/50
# 782/782 [==============================] - 2s 3ms/step - loss: 2.7361 - accuracy: 0.3201 - val_loss: 2.9673 - val_accuracy: 0.2741
# Epoch 29/50
# 782/782 [==============================] - 3s 3ms/step - loss: 2.7137 - accuracy: 0.3253 - val_loss: 2.8843 - val_accuracy: 0.2962
# Epoch 30/50
# 782/782 [==============================] - 3s 3ms/step - loss: 2.6908 - accuracy: 0.3279 - val_loss: 2.9616 - val_accuracy: 0.2839
# Epoch 31/50
# 782/782 [==============================] - 3s 3ms/step - loss: 2.6700 - accuracy: 0.3329 - val_loss: 2.9155 - val_accuracy: 0.2884
# Epoch 32/50
# 782/782 [==============================] - 2s 3ms/step - loss: 2.6482 - accuracy: 0.3381 - val_loss: 2.8154 - val_accuracy: 0.3081
# Epoch 33/50
# 782/782 [==============================] - 2s 3ms/step - loss: 2.6303 - accuracy: 0.3428 - val_loss: 2.8257 - val_accuracy: 0.3024
# Epoch 34/50
# 782/782 [==============================] - 2s 3ms/step - loss: 2.6098 - accuracy: 0.3472 - val_loss: 2.8159 - val_accuracy: 0.3084
# Epoch 35/50
# 782/782 [==============================] - 2s 3ms/step - loss: 2.5888 - accuracy: 0.3488 - val_loss: 2.7870 - val_accuracy: 0.3130
# Epoch 36/50
# 782/782 [==============================] - 2s 3ms/step - loss: 2.5705 - accuracy: 0.3539 - val_loss: 2.8344 - val_accuracy: 0.3047
# Epoch 37/50
# 782/782 [==============================] - 2s 3ms/step - loss: 2.5505 - accuracy: 0.3577 - val_loss: 2.8426 - val_accuracy: 0.3099
# Epoch 38/50
# 782/782 [==============================] - 2s 3ms/step - loss: 2.5328 - accuracy: 0.3622 - val_loss: 2.8642 - val_accuracy: 0.3016
# Epoch 39/50
# 782/782 [==============================] - 2s 3ms/step - loss: 2.5152 - accuracy: 0.3667 - val_loss: 2.7717 - val_accuracy: 0.3165
# Epoch 40/50
# 782/782 [==============================] - 2s 3ms/step - loss: 2.4969 - accuracy: 0.3703 - val_loss: 2.8777 - val_accuracy: 0.2999
# Epoch 41/50
# 782/782 [==============================] - 2s 3ms/step - loss: 2.4807 - accuracy: 0.3743 - val_loss: 2.7064 - val_accuracy: 0.3334
# Epoch 42/50
# 782/782 [==============================] - 2s 3ms/step - loss: 2.4635 - accuracy: 0.3773 - val_loss: 2.8042 - val_accuracy: 0.3154
# Epoch 43/50
# 782/782 [==============================] - 2s 3ms/step - loss: 2.4512 - accuracy: 0.3800 - val_loss: 2.6902 - val_accuracy: 0.3383
# Epoch 44/50
# 782/782 [==============================] - 2s 3ms/step - loss: 2.4342 - accuracy: 0.3825 - val_loss: 2.8228 - val_accuracy: 0.3129
# Epoch 45/50
# 782/782 [==============================] - 2s 3ms/step - loss: 2.4155 - accuracy: 0.3863 - val_loss: 2.7705 - val_accuracy: 0.3226
# Epoch 46/50
# 782/782 [==============================] - 3s 3ms/step - loss: 2.4034 - accuracy: 0.3889 - val_loss: 2.7422 - val_accuracy: 0.3234
# Epoch 47/50
# 782/782 [==============================] - 2s 3ms/step - loss: 2.3902 - accuracy: 0.3912 - val_loss: 2.7930 - val_accuracy: 0.3183
# Epoch 48/50
# 782/782 [==============================] - 2s 3ms/step - loss: 2.3753 - accuracy: 0.3926 - val_loss: 2.7666 - val_accuracy: 0.3154
# Epoch 49/50
# 782/782 [==============================] - 3s 3ms/step - loss: 2.3600 - accuracy: 0.3982 - val_loss: 2.6401 - val_accuracy: 0.3418
# Epoch 50/50
# 782/782 [==============================] - 2s 3ms/step - loss: 2.3488 - accuracy: 0.4009 - val_loss: 2.6524 - val_accuracy: 0.3426

# %% [markdown]
# Проверка точности предсказания

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 2.6524 - accuracy: 0.3426

# %% [markdown]
# Графики

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
print(plt.show())
# Out:
# None
