# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from tensorflow.keras.datasets import cifar100
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten, Conv2D, MaxPooling2D
from tensorflow.keras import utils, optimizers

# %% [markdown]
# Делим наш датасет на обучающую и тестовую выборку

# %%
(train_images, train_labels), (test_images, test_labels) = cifar100.load_data()

# %%
print('train_images: ', train_images.shape)
print('test_images: ', test_images.shape)
print('train_labels: ', train_labels.shape)
print('test_labels: ', test_labels.shape)
# Out:
# train_images:  (50000, 32, 32, 3)
# test_images:  (10000, 32, 32, 3)
# train_labels:  (50000, 1)
# test_labels:  (10000, 1)

# %% [markdown]
# Нормализация данных

# %%
train_labels = utils.to_categorical(train_labels, 100)
test_labels = utils.to_categorical(test_labels, 100)

train_images = train_images.astype('float32')
test_images = test_images.astype('float32')

train_images = train_images / 255
test_images = test_images / 255

# %% [markdown]
# создание модели нейронной сети

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', input_shape=(32, 32, 3)))
model.add(MaxPooling2D(2, 2))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(2, 2))
model.add(Conv2D(64, (3, 3), activation='relu'))
model.add(MaxPooling2D(2, 2))

model.add(Flatten())
model.add(Dense(64, activation='relu'))
model.add(Dense(100, activation='softmax'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 30, 30, 32)        896
#
#  max_pooling2d (MaxPooling2D  (None, 15, 15, 32)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 13, 13, 64)        18496
#
#  max_pooling2d_1 (MaxPooling  (None, 6, 6, 64)         0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 4, 4, 64)          36928
#
#  max_pooling2d_2 (MaxPooling  (None, 2, 2, 64)         0
#  2D)
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 64)                16448
#
#  dense_1 (Dense)             (None, 100)               6500
#
# =================================================================
# Total params: 79,268
# Trainable params: 79,268
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# Компиляция модели

# %%
model.compile(optimizer=optimizers.RMSprop(learning_rate=5e-4),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# Обучение модели

# %%
epochs = 50
batch_size = 64

hist = model.fit(train_images, train_labels, batch_size=batch_size, validation_data=(test_images, test_labels),
                 epochs=epochs)
# Out:
# Epoch 1/50
# 782/782 [==============================] - 5s 4ms/step - loss: 4.2629 - accuracy: 0.0502 - val_loss: 4.0469 - val_accuracy: 0.0838
# Epoch 2/50
# 782/782 [==============================] - 3s 3ms/step - loss: 3.8346 - accuracy: 0.1160 - val_loss: 3.7730 - val_accuracy: 0.1290
# Epoch 3/50
# 782/782 [==============================] - 3s 3ms/step - loss: 3.5673 - accuracy: 0.1641 - val_loss: 3.5044 - val_accuracy: 0.1694
# Epoch 4/50
# 782/782 [==============================] - 3s 3ms/step - loss: 3.3676 - accuracy: 0.1965 - val_loss: 3.4363 - val_accuracy: 0.1835
# Epoch 5/50
# 782/782 [==============================] - 3s 4ms/step - loss: 3.2121 - accuracy: 0.2242 - val_loss: 3.3087 - val_accuracy: 0.2080
# Epoch 6/50
# 782/782 [==============================] - 3s 4ms/step - loss: 3.0894 - accuracy: 0.2470 - val_loss: 3.1125 - val_accuracy: 0.2435
# Epoch 7/50
# 782/782 [==============================] - 3s 4ms/step - loss: 2.9843 - accuracy: 0.2663 - val_loss: 3.0178 - val_accuracy: 0.2599
# Epoch 8/50
# 782/782 [==============================] - 3s 4ms/step - loss: 2.8902 - accuracy: 0.2856 - val_loss: 2.9809 - val_accuracy: 0.2731
# Epoch 9/50
# 782/782 [==============================] - 3s 4ms/step - loss: 2.8045 - accuracy: 0.3007 - val_loss: 3.0114 - val_accuracy: 0.2675
# Epoch 10/50
# 782/782 [==============================] - 3s 4ms/step - loss: 2.7265 - accuracy: 0.3174 - val_loss: 2.9571 - val_accuracy: 0.2767
# Epoch 11/50
# 782/782 [==============================] - 3s 4ms/step - loss: 2.6526 - accuracy: 0.3315 - val_loss: 2.8300 - val_accuracy: 0.3015
# Epoch 12/50
# 782/782 [==============================] - 3s 4ms/step - loss: 2.5877 - accuracy: 0.3474 - val_loss: 2.7197 - val_accuracy: 0.3206
# Epoch 13/50
# 782/782 [==============================] - 3s 4ms/step - loss: 2.5308 - accuracy: 0.3578 - val_loss: 2.6748 - val_accuracy: 0.3326
# Epoch 14/50
# 782/782 [==============================] - 3s 4ms/step - loss: 2.4783 - accuracy: 0.3693 - val_loss: 2.8658 - val_accuracy: 0.2995
# Epoch 15/50
# 782/782 [==============================] - 3s 4ms/step - loss: 2.4284 - accuracy: 0.3805 - val_loss: 2.7832 - val_accuracy: 0.3135
# Epoch 16/50
# 782/782 [==============================] - 3s 4ms/step - loss: 2.3843 - accuracy: 0.3868 - val_loss: 2.6932 - val_accuracy: 0.3304
# Epoch 17/50
# 782/782 [==============================] - 3s 4ms/step - loss: 2.3366 - accuracy: 0.3995 - val_loss: 2.8554 - val_accuracy: 0.3097
# Epoch 18/50
# 782/782 [==============================] - 3s 4ms/step - loss: 2.2973 - accuracy: 0.4072 - val_loss: 2.6014 - val_accuracy: 0.3534
# Epoch 19/50
# 782/782 [==============================] - 3s 4ms/step - loss: 2.2596 - accuracy: 0.4137 - val_loss: 2.6414 - val_accuracy: 0.3413
# Epoch 20/50
# 782/782 [==============================] - 3s 4ms/step - loss: 2.2232 - accuracy: 0.4225 - val_loss: 2.7149 - val_accuracy: 0.3356
# Epoch 21/50
# 782/782 [==============================] - 3s 4ms/step - loss: 2.1863 - accuracy: 0.4310 - val_loss: 2.5910 - val_accuracy: 0.3571
# Epoch 22/50
# 782/782 [==============================] - 3s 4ms/step - loss: 2.1537 - accuracy: 0.4385 - val_loss: 2.5455 - val_accuracy: 0.3644
# Epoch 23/50
# 782/782 [==============================] - 3s 4ms/step - loss: 2.1205 - accuracy: 0.4451 - val_loss: 2.7376 - val_accuracy: 0.3367
# Epoch 24/50
# 782/782 [==============================] - 3s 4ms/step - loss: 2.0858 - accuracy: 0.4554 - val_loss: 2.5712 - val_accuracy: 0.3594
# Epoch 25/50
# 782/782 [==============================] - 3s 4ms/step - loss: 2.0566 - accuracy: 0.4594 - val_loss: 2.5870 - val_accuracy: 0.3659
# Epoch 26/50
# 782/782 [==============================] - 3s 4ms/step - loss: 2.0258 - accuracy: 0.4645 - val_loss: 2.6306 - val_accuracy: 0.3695
# Epoch 27/50
# 782/782 [==============================] - 3s 4ms/step - loss: 2.0021 - accuracy: 0.4699 - val_loss: 2.5176 - val_accuracy: 0.3767
# Epoch 28/50
# 782/782 [==============================] - 3s 4ms/step - loss: 1.9757 - accuracy: 0.4766 - val_loss: 2.4849 - val_accuracy: 0.3788
# Epoch 29/50
# 782/782 [==============================] - 3s 4ms/step - loss: 1.9496 - accuracy: 0.4817 - val_loss: 2.6483 - val_accuracy: 0.3622
# Epoch 30/50
# 782/782 [==============================] - 3s 4ms/step - loss: 1.9256 - accuracy: 0.4890 - val_loss: 2.5485 - val_accuracy: 0.3686
# Epoch 31/50
# 782/782 [==============================] - 3s 4ms/step - loss: 1.8989 - accuracy: 0.4949 - val_loss: 2.6995 - val_accuracy: 0.3527
# Epoch 32/50
# 782/782 [==============================] - 3s 4ms/step - loss: 1.8777 - accuracy: 0.4974 - val_loss: 2.5408 - val_accuracy: 0.3829
# Epoch 33/50
# 782/782 [==============================] - 3s 4ms/step - loss: 1.8575 - accuracy: 0.5024 - val_loss: 2.5458 - val_accuracy: 0.3766
# Epoch 34/50
# 782/782 [==============================] - 3s 4ms/step - loss: 1.8325 - accuracy: 0.5063 - val_loss: 2.6320 - val_accuracy: 0.3673
# Epoch 35/50
# 782/782 [==============================] - 3s 4ms/step - loss: 1.8127 - accuracy: 0.5123 - val_loss: 2.6950 - val_accuracy: 0.3617
# Epoch 36/50
# 782/782 [==============================] - 3s 4ms/step - loss: 1.7926 - accuracy: 0.5172 - val_loss: 2.5087 - val_accuracy: 0.3902
# Epoch 37/50
# 782/782 [==============================] - 3s 4ms/step - loss: 1.7703 - accuracy: 0.5212 - val_loss: 2.5184 - val_accuracy: 0.3901
# Epoch 38/50
# 782/782 [==============================] - 3s 4ms/step - loss: 1.7515 - accuracy: 0.5264 - val_loss: 2.5504 - val_accuracy: 0.3814
# Epoch 39/50
# 782/782 [==============================] - 3s 4ms/step - loss: 1.7344 - accuracy: 0.5308 - val_loss: 2.6044 - val_accuracy: 0.3845
# Epoch 40/50
# 782/782 [==============================] - 3s 4ms/step - loss: 1.7149 - accuracy: 0.5332 - val_loss: 2.6747 - val_accuracy: 0.3698
# Epoch 41/50
# 782/782 [==============================] - 3s 4ms/step - loss: 1.6954 - accuracy: 0.5407 - val_loss: 2.6627 - val_accuracy: 0.3657
# Epoch 42/50
# 782/782 [==============================] - 3s 4ms/step - loss: 1.6790 - accuracy: 0.5390 - val_loss: 2.6826 - val_accuracy: 0.3700
# Epoch 43/50
# 782/782 [==============================] - 3s 4ms/step - loss: 1.6626 - accuracy: 0.5463 - val_loss: 2.5797 - val_accuracy: 0.3932
# Epoch 44/50
# 782/782 [==============================] - 3s 4ms/step - loss: 1.6453 - accuracy: 0.5508 - val_loss: 2.6766 - val_accuracy: 0.3695
# Epoch 45/50
# 782/782 [==============================] - 3s 4ms/step - loss: 1.6265 - accuracy: 0.5528 - val_loss: 2.5816 - val_accuracy: 0.3926
# Epoch 46/50
# 782/782 [==============================] - 3s 4ms/step - loss: 1.6096 - accuracy: 0.5576 - val_loss: 2.7341 - val_accuracy: 0.3685
# Epoch 47/50
# 782/782 [==============================] - 3s 4ms/step - loss: 1.5959 - accuracy: 0.5609 - val_loss: 2.6826 - val_accuracy: 0.3788
# Epoch 48/50
# 782/782 [==============================] - 3s 4ms/step - loss: 1.5805 - accuracy: 0.5646 - val_loss: 2.8708 - val_accuracy: 0.3631
# Epoch 49/50
# 782/782 [==============================] - 3s 4ms/step - loss: 1.5639 - accuracy: 0.5678 - val_loss: 2.7824 - val_accuracy: 0.3719
# Epoch 50/50
# 782/782 [==============================] - 3s 4ms/step - loss: 1.5464 - accuracy: 0.5713 - val_loss: 2.7009 - val_accuracy: 0.3771

# %% [markdown]
# Проверка точности предсказания

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 2.7009 - accuracy: 0.3771

# %% [markdown]
# Графики

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
print(plt.show())
# Out:
# None
