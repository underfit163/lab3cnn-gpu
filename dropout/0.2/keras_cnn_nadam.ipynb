# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from tensorflow.keras.datasets import cifar100
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Dense, Flatten, Conv2D, MaxPooling2D, Activation, BatchNormalization
from tensorflow.keras import utils, optimizers, regularizers

# %% [markdown]
# Делим наш датасет на обучающую и тестовую выборку

# %%
(train_images, train_labels), (test_images, test_labels) = cifar100.load_data()

# %% [markdown]
# Нормализация данных

# %%
train_labels = utils.to_categorical(train_labels, 100)
test_labels = utils.to_categorical(test_labels, 100)

train_images = train_images.astype('float32')
test_images = test_images.astype('float32')

train_images = train_images / 255
test_images = test_images / 255

# %% [markdown]
# создание модели нейронной сети

# %%
dropP = 0.2

model = Sequential()

model.add(Conv2D(128,(3,3),padding='same',input_shape=(32,32,3)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(128,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(dropP))

model.add(Conv2D(256,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(256,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(dropP))

model.add(Conv2D(256,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(256,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(dropP))

model.add(Flatten())
model.add(Dense(512, kernel_regularizer=regularizers.L2(1e-4)))
model.add(Activation('relu'))
model.add(Dropout(dropP))
model.add(BatchNormalization())
model.add(Dense(100,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 128)       3584
#
#  batch_normalization (BatchN  (None, 32, 32, 128)      512
#  ormalization)
#
#  activation (Activation)     (None, 32, 32, 128)       0
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 128)       147584
#
#  batch_normalization_1 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  activation_1 (Activation)   (None, 32, 32, 128)       0
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 128)      0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 256)       295168
#
#  batch_normalization_2 (Batc  (None, 16, 16, 256)      1024
#  hNormalization)
#
#  activation_2 (Activation)   (None, 16, 16, 256)       0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 256)       590080
#
#  batch_normalization_3 (Batc  (None, 16, 16, 256)      1024
#  hNormalization)
#
#  activation_3 (Activation)   (None, 16, 16, 256)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 256)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 256)         0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 256)         590080
#
#  batch_normalization_4 (Batc  (None, 8, 8, 256)        1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 8, 8, 256)         0
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 256)         590080
#
#  batch_normalization_5 (Batc  (None, 8, 8, 256)        1024
#  hNormalization)
#
#  activation_5 (Activation)   (None, 8, 8, 256)         0
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 256)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 256)         0
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 512)               2097664
#
#  activation_6 (Activation)   (None, 512)               0
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  batch_normalization_6 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_1 (Dense)             (None, 100)               51300
#
# =================================================================
# Total params: 4,372,708
# Trainable params: 4,369,124
# Non-trainable params: 3,584
# _________________________________________________________________

# %% [markdown]
# Компиляция модели

# %%
model.compile(optimizer=optimizers.Nadam(),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# Обучение модели

# %%
epochs = 50
batch_size = 64

hist = model.fit(train_images, train_labels, batch_size=batch_size, validation_data=(test_images, test_labels),
                 epochs=epochs)
# Out:
# Epoch 1/50
# 782/782 [==============================] - 26s 30ms/step - loss: 3.4893 - accuracy: 0.1948 - val_loss: 3.4384 - val_accuracy: 0.2049
# Epoch 2/50
# 782/782 [==============================] - 23s 29ms/step - loss: 2.5302 - accuracy: 0.3739 - val_loss: 3.1883 - val_accuracy: 0.2706
# Epoch 3/50
# 782/782 [==============================] - 23s 29ms/step - loss: 2.1709 - accuracy: 0.4577 - val_loss: 2.5438 - val_accuracy: 0.3805
# Epoch 4/50
# 782/782 [==============================] - 23s 29ms/step - loss: 1.9481 - accuracy: 0.5104 - val_loss: 2.1471 - val_accuracy: 0.4719
# Epoch 5/50
# 782/782 [==============================] - 23s 29ms/step - loss: 1.7995 - accuracy: 0.5519 - val_loss: 2.3137 - val_accuracy: 0.4407
# Epoch 6/50
# 782/782 [==============================] - 23s 30ms/step - loss: 1.6659 - accuracy: 0.5897 - val_loss: 1.9703 - val_accuracy: 0.5331
# Epoch 7/50
# 782/782 [==============================] - 23s 30ms/step - loss: 1.5362 - accuracy: 0.6232 - val_loss: 2.2018 - val_accuracy: 0.4875
# Epoch 8/50
# 782/782 [==============================] - 23s 30ms/step - loss: 1.4185 - accuracy: 0.6573 - val_loss: 2.1283 - val_accuracy: 0.5226
# Epoch 9/50
# 782/782 [==============================] - 23s 30ms/step - loss: 1.3133 - accuracy: 0.6884 - val_loss: 2.2560 - val_accuracy: 0.4950
# Epoch 10/50
# 782/782 [==============================] - 24s 30ms/step - loss: 1.2084 - accuracy: 0.7197 - val_loss: 1.9239 - val_accuracy: 0.5717
# Epoch 11/50
# 782/782 [==============================] - 24s 30ms/step - loss: 1.1096 - accuracy: 0.7487 - val_loss: 2.1931 - val_accuracy: 0.5354
# Epoch 12/50
# 782/782 [==============================] - 24s 31ms/step - loss: 1.0533 - accuracy: 0.7685 - val_loss: 2.0113 - val_accuracy: 0.5657
# Epoch 13/50
# 782/782 [==============================] - 24s 31ms/step - loss: 0.9872 - accuracy: 0.7903 - val_loss: 2.1103 - val_accuracy: 0.5554
# Epoch 14/50
# 782/782 [==============================] - 24s 31ms/step - loss: 0.9291 - accuracy: 0.8105 - val_loss: 2.3931 - val_accuracy: 0.5453
# Epoch 15/50
# 782/782 [==============================] - 24s 31ms/step - loss: 0.8915 - accuracy: 0.8240 - val_loss: 2.1876 - val_accuracy: 0.5557
# Epoch 16/50
# 782/782 [==============================] - 24s 30ms/step - loss: 0.8541 - accuracy: 0.8412 - val_loss: 2.1320 - val_accuracy: 0.5912
# Epoch 17/50
# 782/782 [==============================] - 24s 31ms/step - loss: 0.8207 - accuracy: 0.8525 - val_loss: 2.2136 - val_accuracy: 0.5813
# Epoch 18/50
# 782/782 [==============================] - 24s 31ms/step - loss: 0.8056 - accuracy: 0.8588 - val_loss: 2.2606 - val_accuracy: 0.5857
# Epoch 19/50
# 782/782 [==============================] - 24s 31ms/step - loss: 0.7820 - accuracy: 0.8705 - val_loss: 2.2959 - val_accuracy: 0.5939
# Epoch 20/50
# 782/782 [==============================] - 24s 30ms/step - loss: 0.7648 - accuracy: 0.8757 - val_loss: 2.2470 - val_accuracy: 0.5881
# Epoch 21/50
# 782/782 [==============================] - 24s 30ms/step - loss: 0.7523 - accuracy: 0.8811 - val_loss: 2.3073 - val_accuracy: 0.5964
# Epoch 22/50
# 782/782 [==============================] - 24s 31ms/step - loss: 0.7397 - accuracy: 0.8871 - val_loss: 2.4070 - val_accuracy: 0.5829
# Epoch 23/50
# 782/782 [==============================] - 24s 31ms/step - loss: 0.7293 - accuracy: 0.8916 - val_loss: 2.3423 - val_accuracy: 0.5949
# Epoch 24/50
# 782/782 [==============================] - 24s 31ms/step - loss: 0.7348 - accuracy: 0.8895 - val_loss: 2.3144 - val_accuracy: 0.5936
# Epoch 25/50
# 782/782 [==============================] - 24s 30ms/step - loss: 0.7047 - accuracy: 0.9000 - val_loss: 2.5479 - val_accuracy: 0.5737
# Epoch 26/50
# 782/782 [==============================] - 24s 30ms/step - loss: 0.7077 - accuracy: 0.8987 - val_loss: 2.5858 - val_accuracy: 0.5760
# Epoch 27/50
# 782/782 [==============================] - 24s 30ms/step - loss: 0.6948 - accuracy: 0.9034 - val_loss: 2.2960 - val_accuracy: 0.6141
# Epoch 28/50
# 782/782 [==============================] - 24s 31ms/step - loss: 0.6872 - accuracy: 0.9054 - val_loss: 2.3160 - val_accuracy: 0.6134
# Epoch 29/50
# 782/782 [==============================] - 24s 30ms/step - loss: 0.6778 - accuracy: 0.9094 - val_loss: 2.4219 - val_accuracy: 0.6005
# Epoch 30/50
# 782/782 [==============================] - 24s 30ms/step - loss: 0.6746 - accuracy: 0.9099 - val_loss: 2.4412 - val_accuracy: 0.5993
# Epoch 31/50
# 782/782 [==============================] - 24s 30ms/step - loss: 0.6689 - accuracy: 0.9114 - val_loss: 2.4470 - val_accuracy: 0.6050
# Epoch 32/50
# 782/782 [==============================] - 24s 31ms/step - loss: 0.6635 - accuracy: 0.9133 - val_loss: 2.7828 - val_accuracy: 0.5582
# Epoch 33/50
# 782/782 [==============================] - 24s 31ms/step - loss: 0.6693 - accuracy: 0.9120 - val_loss: 2.3443 - val_accuracy: 0.6111
# Epoch 34/50
# 782/782 [==============================] - 24s 31ms/step - loss: 0.6533 - accuracy: 0.9143 - val_loss: 2.3644 - val_accuracy: 0.6010
# Epoch 35/50
# 782/782 [==============================] - 24s 30ms/step - loss: 0.6468 - accuracy: 0.9182 - val_loss: 2.4270 - val_accuracy: 0.6077
# Epoch 36/50
# 782/782 [==============================] - 24s 31ms/step - loss: 0.6295 - accuracy: 0.9235 - val_loss: 2.6024 - val_accuracy: 0.5778
# Epoch 37/50
# 782/782 [==============================] - 24s 31ms/step - loss: 0.6402 - accuracy: 0.9179 - val_loss: 2.4903 - val_accuracy: 0.6081
# Epoch 38/50
# 782/782 [==============================] - 24s 31ms/step - loss: 0.6327 - accuracy: 0.9222 - val_loss: 2.5103 - val_accuracy: 0.6117
# Epoch 39/50
# 782/782 [==============================] - 24s 31ms/step - loss: 0.6206 - accuracy: 0.9258 - val_loss: 2.5021 - val_accuracy: 0.6171
# Epoch 40/50
# 782/782 [==============================] - 24s 31ms/step - loss: 0.6215 - accuracy: 0.9246 - val_loss: 2.4128 - val_accuracy: 0.6043
# Epoch 41/50
# 782/782 [==============================] - 24s 31ms/step - loss: 0.6116 - accuracy: 0.9258 - val_loss: 2.4009 - val_accuracy: 0.6105
# Epoch 42/50
# 782/782 [==============================] - 24s 31ms/step - loss: 0.6014 - accuracy: 0.9293 - val_loss: 2.5887 - val_accuracy: 0.5916
# Epoch 43/50
# 782/782 [==============================] - 24s 31ms/step - loss: 0.5969 - accuracy: 0.9307 - val_loss: 2.6649 - val_accuracy: 0.5937
# Epoch 44/50
# 782/782 [==============================] - 24s 31ms/step - loss: 0.5933 - accuracy: 0.9306 - val_loss: 2.5331 - val_accuracy: 0.6116
# Epoch 45/50
# 782/782 [==============================] - 24s 31ms/step - loss: 0.5960 - accuracy: 0.9307 - val_loss: 2.6129 - val_accuracy: 0.5996
# Epoch 46/50
# 782/782 [==============================] - 24s 31ms/step - loss: 0.5859 - accuracy: 0.9333 - val_loss: 2.5163 - val_accuracy: 0.6134
# Epoch 47/50
# 782/782 [==============================] - 24s 31ms/step - loss: 0.5835 - accuracy: 0.9331 - val_loss: 2.5055 - val_accuracy: 0.6093
# Epoch 48/50
# 782/782 [==============================] - 24s 31ms/step - loss: 0.5826 - accuracy: 0.9333 - val_loss: 2.6449 - val_accuracy: 0.6051
# Epoch 49/50
# 782/782 [==============================] - 24s 31ms/step - loss: 0.5786 - accuracy: 0.9343 - val_loss: 2.6823 - val_accuracy: 0.5959
# Epoch 50/50
# 782/782 [==============================] - 24s 31ms/step - loss: 0.5611 - accuracy: 0.9385 - val_loss: 2.4539 - val_accuracy: 0.6114

# %% [markdown]
# Проверка точности предсказания

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 2.4539 - accuracy: 0.6114

# %% [markdown]
# Графики

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
print(plt.show())
# Out:
# None
