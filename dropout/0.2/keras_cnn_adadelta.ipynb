# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from tensorflow.keras.datasets import cifar100
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Dense, Flatten, Conv2D, MaxPooling2D, Activation, BatchNormalization
from tensorflow.keras import utils, optimizers, regularizers

# %% [markdown]
# Делим наш датасет на обучающую и тестовую выборку

# %%
(train_images, train_labels), (test_images, test_labels) = cifar100.load_data()

# %%
print('train_images: ', train_images.shape)
print('test_images: ', test_images.shape)
print('train_labels: ', train_labels.shape)
print('test_labels: ', test_labels.shape)
# Out:
# train_images:  (50000, 32, 32, 3)
# test_images:  (10000, 32, 32, 3)
# train_labels:  (50000, 1)
# test_labels:  (10000, 1)

# %% [markdown]
# Нормализация данных

# %%
train_labels = utils.to_categorical(train_labels, 100)
test_labels = utils.to_categorical(test_labels, 100)

train_images = train_images.astype('float32')
test_images = test_images.astype('float32')

train_images = train_images / 255
test_images = test_images / 255

# %% [markdown]
# создание модели нейронной сети

# %%
dropP = 0.2

model = Sequential()

model.add(Conv2D(128,(3,3),padding='same',input_shape=(32,32,3)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(128,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(dropP))

model.add(Conv2D(256,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(256,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(dropP))

model.add(Conv2D(256,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(256,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(dropP))

model.add(Flatten())
model.add(Dense(512, kernel_regularizer=regularizers.L2(1e-4)))
model.add(Activation('relu'))
model.add(Dropout(dropP))
model.add(BatchNormalization())
model.add(Dense(100,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 128)       3584
#
#  batch_normalization (BatchN  (None, 32, 32, 128)      512
#  ormalization)
#
#  activation (Activation)     (None, 32, 32, 128)       0
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 128)       147584
#
#  batch_normalization_1 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  activation_1 (Activation)   (None, 32, 32, 128)       0
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 128)      0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 256)       295168
#
#  batch_normalization_2 (Batc  (None, 16, 16, 256)      1024
#  hNormalization)
#
#  activation_2 (Activation)   (None, 16, 16, 256)       0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 256)       590080
#
#  batch_normalization_3 (Batc  (None, 16, 16, 256)      1024
#  hNormalization)
#
#  activation_3 (Activation)   (None, 16, 16, 256)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 256)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 256)         0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 256)         590080
#
#  batch_normalization_4 (Batc  (None, 8, 8, 256)        1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 8, 8, 256)         0
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 256)         590080
#
#  batch_normalization_5 (Batc  (None, 8, 8, 256)        1024
#  hNormalization)
#
#  activation_5 (Activation)   (None, 8, 8, 256)         0
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 256)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 256)         0
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 512)               2097664
#
#  activation_6 (Activation)   (None, 512)               0
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  batch_normalization_6 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_1 (Dense)             (None, 100)               51300
#
# =================================================================
# Total params: 4,372,708
# Trainable params: 4,369,124
# Non-trainable params: 3,584
# _________________________________________________________________

# %% [markdown]
# Компиляция модели

# %%
model.compile(optimizer=optimizers.Adadelta(learning_rate=0.15),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# Обучение модели

# %%
epochs = 50
batch_size = 64

hist = model.fit(train_images, train_labels, batch_size=batch_size, validation_data=(test_images, test_labels),
                 epochs=epochs)
# Out:
# Epoch 1/50
# 782/782 [==============================] - 23s 26ms/step - loss: 3.9765 - accuracy: 0.1243 - val_loss: 3.8669 - val_accuracy: 0.1386
# Epoch 2/50
# 782/782 [==============================] - 20s 25ms/step - loss: 3.1866 - accuracy: 0.2515 - val_loss: 3.1154 - val_accuracy: 0.2708
# Epoch 3/50
# 782/782 [==============================] - 20s 25ms/step - loss: 2.7030 - accuracy: 0.3448 - val_loss: 3.7689 - val_accuracy: 0.1995
# Epoch 4/50
# 782/782 [==============================] - 20s 25ms/step - loss: 2.3678 - accuracy: 0.4127 - val_loss: 2.4855 - val_accuracy: 0.3942
# Epoch 5/50
# 782/782 [==============================] - 20s 25ms/step - loss: 2.1295 - accuracy: 0.4657 - val_loss: 2.6593 - val_accuracy: 0.3500
# Epoch 6/50
# 782/782 [==============================] - 20s 25ms/step - loss: 1.9312 - accuracy: 0.5110 - val_loss: 2.0595 - val_accuracy: 0.4779
# Epoch 7/50
# 782/782 [==============================] - 20s 25ms/step - loss: 1.7720 - accuracy: 0.5455 - val_loss: 2.0851 - val_accuracy: 0.4801
# Epoch 8/50
# 782/782 [==============================] - 20s 25ms/step - loss: 1.6322 - accuracy: 0.5812 - val_loss: 2.0729 - val_accuracy: 0.4864
# Epoch 9/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.5147 - accuracy: 0.6082 - val_loss: 2.0309 - val_accuracy: 0.4947
# Epoch 10/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.4042 - accuracy: 0.6368 - val_loss: 1.9605 - val_accuracy: 0.5083
# Epoch 11/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.3054 - accuracy: 0.6600 - val_loss: 1.9511 - val_accuracy: 0.5184
# Epoch 12/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.2039 - accuracy: 0.6868 - val_loss: 1.7834 - val_accuracy: 0.5449
# Epoch 13/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.1172 - accuracy: 0.7098 - val_loss: 1.8146 - val_accuracy: 0.5456
# Epoch 14/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.0374 - accuracy: 0.7311 - val_loss: 1.8899 - val_accuracy: 0.5388
# Epoch 15/50
# 782/782 [==============================] - 20s 26ms/step - loss: 0.9660 - accuracy: 0.7516 - val_loss: 1.6722 - val_accuracy: 0.5804
# Epoch 16/50
# 782/782 [==============================] - 20s 26ms/step - loss: 0.8964 - accuracy: 0.7693 - val_loss: 1.7314 - val_accuracy: 0.5661
# Epoch 17/50
# 782/782 [==============================] - 20s 26ms/step - loss: 0.8329 - accuracy: 0.7872 - val_loss: 1.7013 - val_accuracy: 0.5758
# Epoch 18/50
# 782/782 [==============================] - 20s 26ms/step - loss: 0.7670 - accuracy: 0.8066 - val_loss: 1.7263 - val_accuracy: 0.5773
# Epoch 19/50
# 782/782 [==============================] - 20s 26ms/step - loss: 0.7147 - accuracy: 0.8182 - val_loss: 1.8548 - val_accuracy: 0.5413
# Epoch 20/50
# 782/782 [==============================] - 21s 27ms/step - loss: 0.6620 - accuracy: 0.8326 - val_loss: 1.6524 - val_accuracy: 0.5916
# Epoch 21/50
# 782/782 [==============================] - 22s 28ms/step - loss: 0.6104 - accuracy: 0.8483 - val_loss: 1.7818 - val_accuracy: 0.5693
# Epoch 22/50
# 782/782 [==============================] - 22s 28ms/step - loss: 0.5737 - accuracy: 0.8601 - val_loss: 1.7537 - val_accuracy: 0.5813
# Epoch 23/50
# 782/782 [==============================] - 22s 28ms/step - loss: 0.5280 - accuracy: 0.8733 - val_loss: 1.6411 - val_accuracy: 0.6059
# Epoch 24/50
# 782/782 [==============================] - 22s 28ms/step - loss: 0.4991 - accuracy: 0.8806 - val_loss: 1.6896 - val_accuracy: 0.5926
# Epoch 25/50
# 782/782 [==============================] - 21s 27ms/step - loss: 0.4634 - accuracy: 0.8904 - val_loss: 1.7765 - val_accuracy: 0.5905
# Epoch 26/50
# 782/782 [==============================] - 21s 27ms/step - loss: 0.4364 - accuracy: 0.8986 - val_loss: 1.6942 - val_accuracy: 0.6051
# Epoch 27/50
# 782/782 [==============================] - 21s 26ms/step - loss: 0.4051 - accuracy: 0.9074 - val_loss: 1.6562 - val_accuracy: 0.6102
# Epoch 28/50
# 782/782 [==============================] - 20s 26ms/step - loss: 0.3859 - accuracy: 0.9141 - val_loss: 1.6869 - val_accuracy: 0.6082
# Epoch 29/50
# 782/782 [==============================] - 20s 26ms/step - loss: 0.3633 - accuracy: 0.9210 - val_loss: 1.8462 - val_accuracy: 0.5842
# Epoch 30/50
# 782/782 [==============================] - 20s 26ms/step - loss: 0.3446 - accuracy: 0.9257 - val_loss: 1.7759 - val_accuracy: 0.5982
# Epoch 31/50
# 782/782 [==============================] - 21s 26ms/step - loss: 0.3323 - accuracy: 0.9300 - val_loss: 1.9649 - val_accuracy: 0.5873
# Epoch 32/50
# 782/782 [==============================] - 21s 26ms/step - loss: 0.3117 - accuracy: 0.9352 - val_loss: 1.8218 - val_accuracy: 0.5931
# Epoch 33/50
# 782/782 [==============================] - 21s 27ms/step - loss: 0.2979 - accuracy: 0.9402 - val_loss: 1.7958 - val_accuracy: 0.5977
# Epoch 34/50
# 782/782 [==============================] - 21s 27ms/step - loss: 0.2869 - accuracy: 0.9430 - val_loss: 1.7989 - val_accuracy: 0.6067
# Epoch 35/50
# 782/782 [==============================] - 21s 26ms/step - loss: 0.2714 - accuracy: 0.9477 - val_loss: 1.7424 - val_accuracy: 0.6184
# Epoch 36/50
# 782/782 [==============================] - 21s 26ms/step - loss: 0.2651 - accuracy: 0.9479 - val_loss: 1.7994 - val_accuracy: 0.6109
# Epoch 37/50
# 782/782 [==============================] - 21s 26ms/step - loss: 0.2539 - accuracy: 0.9512 - val_loss: 1.7859 - val_accuracy: 0.6083
# Epoch 38/50
# 782/782 [==============================] - 21s 26ms/step - loss: 0.2502 - accuracy: 0.9523 - val_loss: 1.8870 - val_accuracy: 0.5973
# Epoch 39/50
# 782/782 [==============================] - 21s 26ms/step - loss: 0.2395 - accuracy: 0.9562 - val_loss: 1.8293 - val_accuracy: 0.6076
# Epoch 40/50
# 782/782 [==============================] - 21s 26ms/step - loss: 0.2341 - accuracy: 0.9572 - val_loss: 1.8619 - val_accuracy: 0.6079
# Epoch 41/50
# 782/782 [==============================] - 21s 26ms/step - loss: 0.2262 - accuracy: 0.9599 - val_loss: 1.7837 - val_accuracy: 0.6196
# Epoch 42/50
# 782/782 [==============================] - 21s 26ms/step - loss: 0.2190 - accuracy: 0.9612 - val_loss: 1.8470 - val_accuracy: 0.6106
# Epoch 43/50
# 782/782 [==============================] - 21s 26ms/step - loss: 0.2140 - accuracy: 0.9629 - val_loss: 2.1985 - val_accuracy: 0.5654
# Epoch 44/50
# 782/782 [==============================] - 21s 26ms/step - loss: 0.2089 - accuracy: 0.9642 - val_loss: 1.8444 - val_accuracy: 0.6145
# Epoch 45/50
# 782/782 [==============================] - 20s 26ms/step - loss: 0.2011 - accuracy: 0.9671 - val_loss: 1.8505 - val_accuracy: 0.6173
# Epoch 46/50
# 782/782 [==============================] - 21s 26ms/step - loss: 0.1975 - accuracy: 0.9663 - val_loss: 1.9248 - val_accuracy: 0.5998
# Epoch 47/50
# 782/782 [==============================] - 21s 26ms/step - loss: 0.1930 - accuracy: 0.9687 - val_loss: 1.8745 - val_accuracy: 0.6204
# Epoch 48/50
# 782/782 [==============================] - 21s 26ms/step - loss: 0.1913 - accuracy: 0.9685 - val_loss: 1.8871 - val_accuracy: 0.6142
# Epoch 49/50
# 782/782 [==============================] - 21s 26ms/step - loss: 0.1834 - accuracy: 0.9703 - val_loss: 1.9007 - val_accuracy: 0.6112
# Epoch 50/50
# 782/782 [==============================] - 21s 26ms/step - loss: 0.1808 - accuracy: 0.9706 - val_loss: 1.9213 - val_accuracy: 0.6073

# %% [markdown]
# Проверка точности предсказания

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 1.9212 - accuracy: 0.6073

# %% [markdown]
# Графики

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
print(plt.show())
# Out:
# None
