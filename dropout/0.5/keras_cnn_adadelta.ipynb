# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from tensorflow.keras.datasets import cifar100
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Dense, Flatten, Conv2D, MaxPooling2D, Activation, BatchNormalization
from tensorflow.keras import utils, optimizers, regularizers

# %% [markdown]
# Делим наш датасет на обучающую и тестовую выборку

# %%
(train_images, train_labels), (test_images, test_labels) = cifar100.load_data()

# %%
print('train_images: ', train_images.shape)
print('test_images: ', test_images.shape)
print('train_labels: ', train_labels.shape)
print('test_labels: ', test_labels.shape)
# Out:
# train_images:  (50000, 32, 32, 3)
# test_images:  (10000, 32, 32, 3)
# train_labels:  (50000, 1)
# test_labels:  (10000, 1)

# %% [markdown]
# Нормализация данных

# %%
train_labels = utils.to_categorical(train_labels, 100)
test_labels = utils.to_categorical(test_labels, 100)

train_images = train_images.astype('float32')
test_images = test_images.astype('float32')

train_images = train_images / 255
test_images = test_images / 255

# %% [markdown]
# создание модели нейронной сети

# %%
dropP = 0.5

model = Sequential()

model.add(Conv2D(128,(3,3),padding='same',input_shape=(32,32,3)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(128,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(dropP))

model.add(Conv2D(256,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(256,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(dropP))

model.add(Conv2D(256,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(256,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(dropP))

model.add(Flatten())
model.add(Dense(512, kernel_regularizer=regularizers.L2(1e-4)))
model.add(Activation('relu'))
model.add(Dropout(dropP))
model.add(BatchNormalization())
model.add(Dense(100,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 128)       3584
#
#  batch_normalization (BatchN  (None, 32, 32, 128)      512
#  ormalization)
#
#  activation (Activation)     (None, 32, 32, 128)       0
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 128)       147584
#
#  batch_normalization_1 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  activation_1 (Activation)   (None, 32, 32, 128)       0
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 128)      0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 256)       295168
#
#  batch_normalization_2 (Batc  (None, 16, 16, 256)      1024
#  hNormalization)
#
#  activation_2 (Activation)   (None, 16, 16, 256)       0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 256)       590080
#
#  batch_normalization_3 (Batc  (None, 16, 16, 256)      1024
#  hNormalization)
#
#  activation_3 (Activation)   (None, 16, 16, 256)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 256)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 256)         0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 256)         590080
#
#  batch_normalization_4 (Batc  (None, 8, 8, 256)        1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 8, 8, 256)         0
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 256)         590080
#
#  batch_normalization_5 (Batc  (None, 8, 8, 256)        1024
#  hNormalization)
#
#  activation_5 (Activation)   (None, 8, 8, 256)         0
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 256)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 256)         0
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 512)               2097664
#
#  activation_6 (Activation)   (None, 512)               0
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  batch_normalization_6 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_1 (Dense)             (None, 100)               51300
#
# =================================================================
# Total params: 4,372,708
# Trainable params: 4,369,124
# Non-trainable params: 3,584
# _________________________________________________________________

# %% [markdown]
# Компиляция модели

# %%
model.compile(optimizer=optimizers.Adadelta(learning_rate=0.15),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# Обучение модели

# %%
epochs = 50
batch_size = 64

hist = model.fit(train_images, train_labels, batch_size=batch_size, validation_data=(test_images, test_labels),
                 epochs=epochs)
# Out:
# Epoch 1/50
# 782/782 [==============================] - 23s 26ms/step - loss: 4.6790 - accuracy: 0.0413 - val_loss: 4.1751 - val_accuracy: 0.0816
# Epoch 2/50
# 782/782 [==============================] - 20s 26ms/step - loss: 4.1296 - accuracy: 0.0918 - val_loss: 3.9520 - val_accuracy: 0.1169
# Epoch 3/50
# 782/782 [==============================] - 20s 25ms/step - loss: 3.8309 - accuracy: 0.1334 - val_loss: 3.7806 - val_accuracy: 0.1421
# Epoch 4/50
# 782/782 [==============================] - 20s 25ms/step - loss: 3.5857 - accuracy: 0.1704 - val_loss: 3.6529 - val_accuracy: 0.1621
# Epoch 5/50
# 782/782 [==============================] - 20s 25ms/step - loss: 3.3532 - accuracy: 0.2104 - val_loss: 3.2324 - val_accuracy: 0.2394
# Epoch 6/50
# 782/782 [==============================] - 20s 25ms/step - loss: 3.1367 - accuracy: 0.2489 - val_loss: 3.1744 - val_accuracy: 0.2555
# Epoch 7/50
# 782/782 [==============================] - 20s 25ms/step - loss: 2.9428 - accuracy: 0.2833 - val_loss: 2.7121 - val_accuracy: 0.3426
# Epoch 8/50
# 782/782 [==============================] - 20s 25ms/step - loss: 2.7911 - accuracy: 0.3126 - val_loss: 2.6030 - val_accuracy: 0.3524
# Epoch 9/50
# 782/782 [==============================] - 20s 25ms/step - loss: 2.6633 - accuracy: 0.3410 - val_loss: 2.5072 - val_accuracy: 0.3735
# Epoch 10/50
# 782/782 [==============================] - 20s 25ms/step - loss: 2.5499 - accuracy: 0.3623 - val_loss: 2.4827 - val_accuracy: 0.3811
# Epoch 11/50
# 782/782 [==============================] - 20s 25ms/step - loss: 2.4577 - accuracy: 0.3812 - val_loss: 2.3330 - val_accuracy: 0.4127
# Epoch 12/50
# 782/782 [==============================] - 20s 26ms/step - loss: 2.3672 - accuracy: 0.4011 - val_loss: 2.3082 - val_accuracy: 0.4160
# Epoch 13/50
# 782/782 [==============================] - 20s 26ms/step - loss: 2.2864 - accuracy: 0.4184 - val_loss: 2.2399 - val_accuracy: 0.4253
# Epoch 14/50
# 782/782 [==============================] - 20s 26ms/step - loss: 2.2204 - accuracy: 0.4336 - val_loss: 2.2550 - val_accuracy: 0.4189
# Epoch 15/50
# 782/782 [==============================] - 20s 26ms/step - loss: 2.1552 - accuracy: 0.4479 - val_loss: 2.0507 - val_accuracy: 0.4713
# Epoch 16/50
# 782/782 [==============================] - 20s 26ms/step - loss: 2.0999 - accuracy: 0.4604 - val_loss: 1.8831 - val_accuracy: 0.5104
# Epoch 17/50
# 782/782 [==============================] - 20s 26ms/step - loss: 2.0407 - accuracy: 0.4741 - val_loss: 2.0740 - val_accuracy: 0.4681
# Epoch 18/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.9984 - accuracy: 0.4804 - val_loss: 2.0566 - val_accuracy: 0.4762
# Epoch 19/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.9492 - accuracy: 0.4931 - val_loss: 1.8665 - val_accuracy: 0.5142
# Epoch 20/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.9112 - accuracy: 0.5010 - val_loss: 2.0103 - val_accuracy: 0.4807
# Epoch 21/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.8655 - accuracy: 0.5127 - val_loss: 1.8517 - val_accuracy: 0.5196
# Epoch 22/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.8212 - accuracy: 0.5199 - val_loss: 1.8714 - val_accuracy: 0.5156
# Epoch 23/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.7975 - accuracy: 0.5261 - val_loss: 1.7517 - val_accuracy: 0.5397
# Epoch 24/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.7561 - accuracy: 0.5371 - val_loss: 1.8652 - val_accuracy: 0.5147
# Epoch 25/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.7248 - accuracy: 0.5455 - val_loss: 1.7617 - val_accuracy: 0.5358
# Epoch 26/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.6895 - accuracy: 0.5549 - val_loss: 1.7996 - val_accuracy: 0.5313
# Epoch 27/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.6560 - accuracy: 0.5614 - val_loss: 1.7152 - val_accuracy: 0.5415
# Epoch 28/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.6275 - accuracy: 0.5671 - val_loss: 1.6465 - val_accuracy: 0.5728
# Epoch 29/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.6050 - accuracy: 0.5733 - val_loss: 1.8750 - val_accuracy: 0.5192
# Epoch 30/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.5772 - accuracy: 0.5772 - val_loss: 1.9460 - val_accuracy: 0.5020
# Epoch 31/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.5534 - accuracy: 0.5853 - val_loss: 1.6022 - val_accuracy: 0.5761
# Epoch 32/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.5289 - accuracy: 0.5920 - val_loss: 1.6432 - val_accuracy: 0.5672
# Epoch 33/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.5083 - accuracy: 0.5959 - val_loss: 1.6528 - val_accuracy: 0.5714
# Epoch 34/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.4784 - accuracy: 0.6030 - val_loss: 1.6249 - val_accuracy: 0.5729
# Epoch 35/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.4579 - accuracy: 0.6080 - val_loss: 1.6350 - val_accuracy: 0.5710
# Epoch 36/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.4330 - accuracy: 0.6161 - val_loss: 1.5858 - val_accuracy: 0.5807
# Epoch 37/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.4083 - accuracy: 0.6197 - val_loss: 1.5880 - val_accuracy: 0.5847
# Epoch 38/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.3936 - accuracy: 0.6229 - val_loss: 1.5342 - val_accuracy: 0.5942
# Epoch 39/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.3800 - accuracy: 0.6288 - val_loss: 1.5633 - val_accuracy: 0.5855
# Epoch 40/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.3533 - accuracy: 0.6346 - val_loss: 1.7157 - val_accuracy: 0.5532
# Epoch 41/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.3333 - accuracy: 0.6366 - val_loss: 1.6593 - val_accuracy: 0.5706
# Epoch 42/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.3162 - accuracy: 0.6443 - val_loss: 1.5028 - val_accuracy: 0.6051
# Epoch 43/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.3014 - accuracy: 0.6477 - val_loss: 1.5665 - val_accuracy: 0.5911
# Epoch 44/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.2801 - accuracy: 0.6534 - val_loss: 1.6531 - val_accuracy: 0.5697
# Epoch 45/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.2548 - accuracy: 0.6595 - val_loss: 1.7182 - val_accuracy: 0.5699
# Epoch 46/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.2459 - accuracy: 0.6599 - val_loss: 1.4778 - val_accuracy: 0.6112
# Epoch 47/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.2180 - accuracy: 0.6669 - val_loss: 1.4597 - val_accuracy: 0.6141
# Epoch 48/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.2076 - accuracy: 0.6682 - val_loss: 1.4594 - val_accuracy: 0.6158
# Epoch 49/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.1960 - accuracy: 0.6714 - val_loss: 1.5924 - val_accuracy: 0.5899
# Epoch 50/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.1792 - accuracy: 0.6785 - val_loss: 1.4871 - val_accuracy: 0.6182

# %% [markdown]
# Проверка точности предсказания

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 1.4871 - accuracy: 0.6182

# %% [markdown]
# Графики

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
print(plt.show())
# Out:
# None
