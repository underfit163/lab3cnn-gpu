# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from tensorflow.keras.datasets import cifar100
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dropout, Dense, Flatten, Conv2D, MaxPooling2D, Activation, BatchNormalization
from tensorflow.keras import utils, optimizers, regularizers

# %% [markdown]
# Делим наш датасет на обучающую и тестовую выборку

# %%
(train_images, train_labels), (test_images, test_labels) = cifar100.load_data()

# %%
print('train_images: ', train_images.shape)
print('test_images: ', test_images.shape)
print('train_labels: ', train_labels.shape)
print('test_labels: ', test_labels.shape)
# Out:
# train_images:  (50000, 32, 32, 3)
# test_images:  (10000, 32, 32, 3)
# train_labels:  (50000, 1)
# test_labels:  (10000, 1)

# %% [markdown]
# Нормализация данных

# %%
train_labels = utils.to_categorical(train_labels, 100)
test_labels = utils.to_categorical(test_labels, 100)

train_images = train_images.astype('float32')
test_images = test_images.astype('float32')

train_images = train_images / 255
test_images = test_images / 255

# %% [markdown]
# создание модели нейронной сети

# %%
dropP = 0.5

model = Sequential()

model.add(Conv2D(128,(3,3),padding='same',input_shape=(32,32,3)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(128,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(dropP))

model.add(Conv2D(256,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(256,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(dropP))

model.add(Conv2D(256,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Conv2D(256,(3,3),padding='same'))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(dropP))

model.add(Flatten())
model.add(Dense(512, kernel_regularizer=regularizers.L2(1e-4)))
model.add(Activation('relu'))
model.add(Dropout(dropP))
model.add(BatchNormalization())
model.add(Dense(100,activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 32, 32, 128)       3584
#
#  batch_normalization (BatchN  (None, 32, 32, 128)      512
#  ormalization)
#
#  activation (Activation)     (None, 32, 32, 128)       0
#
#  conv2d_1 (Conv2D)           (None, 32, 32, 128)       147584
#
#  batch_normalization_1 (Batc  (None, 32, 32, 128)      512
#  hNormalization)
#
#  activation_1 (Activation)   (None, 32, 32, 128)       0
#
#  max_pooling2d (MaxPooling2D  (None, 16, 16, 128)      0
#  )
#
#  dropout (Dropout)           (None, 16, 16, 128)       0
#
#  conv2d_2 (Conv2D)           (None, 16, 16, 256)       295168
#
#  batch_normalization_2 (Batc  (None, 16, 16, 256)      1024
#  hNormalization)
#
#  activation_2 (Activation)   (None, 16, 16, 256)       0
#
#  conv2d_3 (Conv2D)           (None, 16, 16, 256)       590080
#
#  batch_normalization_3 (Batc  (None, 16, 16, 256)      1024
#  hNormalization)
#
#  activation_3 (Activation)   (None, 16, 16, 256)       0
#
#  max_pooling2d_1 (MaxPooling  (None, 8, 8, 256)        0
#  2D)
#
#  dropout_1 (Dropout)         (None, 8, 8, 256)         0
#
#  conv2d_4 (Conv2D)           (None, 8, 8, 256)         590080
#
#  batch_normalization_4 (Batc  (None, 8, 8, 256)        1024
#  hNormalization)
#
#  activation_4 (Activation)   (None, 8, 8, 256)         0
#
#  conv2d_5 (Conv2D)           (None, 8, 8, 256)         590080
#
#  batch_normalization_5 (Batc  (None, 8, 8, 256)        1024
#  hNormalization)
#
#  activation_5 (Activation)   (None, 8, 8, 256)         0
#
#  max_pooling2d_2 (MaxPooling  (None, 4, 4, 256)        0
#  2D)
#
#  dropout_2 (Dropout)         (None, 4, 4, 256)         0
#
#  flatten (Flatten)           (None, 4096)              0
#
#  dense (Dense)               (None, 512)               2097664
#
#  activation_6 (Activation)   (None, 512)               0
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  batch_normalization_6 (Batc  (None, 512)              2048
#  hNormalization)
#
#  dense_1 (Dense)             (None, 100)               51300
#
# =================================================================
# Total params: 4,372,708
# Trainable params: 4,369,124
# Non-trainable params: 3,584
# _________________________________________________________________

# %% [markdown]
# Компиляция модели

# %%
model.compile(optimizer=optimizers.RMSprop(learning_rate=1e-4),
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# Обучение модели

# %%
epochs = 50
batch_size = 64

hist = model.fit(train_images, train_labels, batch_size=batch_size, validation_data=(test_images, test_labels),
                 epochs=epochs)
# Out:
# Epoch 1/50
# 782/782 [==============================] - 24s 27ms/step - loss: 4.8169 - accuracy: 0.0330 - val_loss: 4.3998 - val_accuracy: 0.0463
# Epoch 2/50
# 782/782 [==============================] - 20s 26ms/step - loss: 4.2223 - accuracy: 0.0798 - val_loss: 4.0019 - val_accuracy: 0.1036
# Epoch 3/50
# 782/782 [==============================] - 20s 26ms/step - loss: 3.9171 - accuracy: 0.1181 - val_loss: 3.7429 - val_accuracy: 0.1501
# Epoch 4/50
# 782/782 [==============================] - 20s 26ms/step - loss: 3.6500 - accuracy: 0.1608 - val_loss: 3.5948 - val_accuracy: 0.1772
# Epoch 5/50
# 782/782 [==============================] - 21s 26ms/step - loss: 3.4228 - accuracy: 0.1994 - val_loss: 3.9155 - val_accuracy: 0.1509
# Epoch 6/50
# 782/782 [==============================] - 21s 27ms/step - loss: 3.2070 - accuracy: 0.2370 - val_loss: 3.0785 - val_accuracy: 0.2642
# Epoch 7/50
# 782/782 [==============================] - 21s 27ms/step - loss: 3.0090 - accuracy: 0.2725 - val_loss: 2.8272 - val_accuracy: 0.3086
# Epoch 8/50
# 782/782 [==============================] - 21s 27ms/step - loss: 2.8464 - accuracy: 0.3040 - val_loss: 2.8287 - val_accuracy: 0.3096
# Epoch 9/50
# 782/782 [==============================] - 21s 27ms/step - loss: 2.7082 - accuracy: 0.3293 - val_loss: 2.5553 - val_accuracy: 0.3639
# Epoch 10/50
# 782/782 [==============================] - 21s 26ms/step - loss: 2.5981 - accuracy: 0.3521 - val_loss: 2.8754 - val_accuracy: 0.3016
# Epoch 11/50
# 782/782 [==============================] - 21s 26ms/step - loss: 2.5039 - accuracy: 0.3739 - val_loss: 2.4135 - val_accuracy: 0.3887
# Epoch 12/50
# 782/782 [==============================] - 21s 26ms/step - loss: 2.4121 - accuracy: 0.3926 - val_loss: 2.1956 - val_accuracy: 0.4397
# Epoch 13/50
# 782/782 [==============================] - 21s 26ms/step - loss: 2.3384 - accuracy: 0.4098 - val_loss: 2.2295 - val_accuracy: 0.4325
# Epoch 14/50
# 782/782 [==============================] - 21s 27ms/step - loss: 2.2687 - accuracy: 0.4251 - val_loss: 2.1663 - val_accuracy: 0.4502
# Epoch 15/50
# 782/782 [==============================] - 20s 26ms/step - loss: 2.2049 - accuracy: 0.4385 - val_loss: 2.0979 - val_accuracy: 0.4603
# Epoch 16/50
# 782/782 [==============================] - 21s 26ms/step - loss: 2.1579 - accuracy: 0.4494 - val_loss: 2.0448 - val_accuracy: 0.4789
# Epoch 17/50
# 782/782 [==============================] - 21s 26ms/step - loss: 2.1049 - accuracy: 0.4583 - val_loss: 1.9346 - val_accuracy: 0.4974
# Epoch 18/50
# 782/782 [==============================] - 21s 26ms/step - loss: 2.0450 - accuracy: 0.4747 - val_loss: 1.9797 - val_accuracy: 0.4953
# Epoch 19/50
# 782/782 [==============================] - 21s 26ms/step - loss: 2.0116 - accuracy: 0.4835 - val_loss: 1.9902 - val_accuracy: 0.4897
# Epoch 20/50
# 782/782 [==============================] - 21s 26ms/step - loss: 1.9694 - accuracy: 0.4915 - val_loss: 1.8897 - val_accuracy: 0.5170
# Epoch 21/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.9289 - accuracy: 0.4995 - val_loss: 1.9259 - val_accuracy: 0.5006
# Epoch 22/50
# 782/782 [==============================] - 21s 26ms/step - loss: 1.8964 - accuracy: 0.5066 - val_loss: 1.8136 - val_accuracy: 0.5253
# Epoch 23/50
# 782/782 [==============================] - 21s 26ms/step - loss: 1.8628 - accuracy: 0.5163 - val_loss: 1.7685 - val_accuracy: 0.5402
# Epoch 24/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.8264 - accuracy: 0.5258 - val_loss: 1.9702 - val_accuracy: 0.5036
# Epoch 25/50
# 782/782 [==============================] - 21s 26ms/step - loss: 1.8016 - accuracy: 0.5310 - val_loss: 1.7749 - val_accuracy: 0.5422
# Epoch 26/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.7676 - accuracy: 0.5362 - val_loss: 1.7470 - val_accuracy: 0.5474
# Epoch 27/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.7364 - accuracy: 0.5453 - val_loss: 1.7142 - val_accuracy: 0.5520
# Epoch 28/50
# 782/782 [==============================] - 21s 26ms/step - loss: 1.7145 - accuracy: 0.5521 - val_loss: 1.8566 - val_accuracy: 0.5284
# Epoch 29/50
# 782/782 [==============================] - 21s 26ms/step - loss: 1.6917 - accuracy: 0.5564 - val_loss: 1.6286 - val_accuracy: 0.5672
# Epoch 30/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.6687 - accuracy: 0.5600 - val_loss: 1.6644 - val_accuracy: 0.5646
# Epoch 31/50
# 782/782 [==============================] - 21s 26ms/step - loss: 1.6352 - accuracy: 0.5700 - val_loss: 1.6540 - val_accuracy: 0.5685
# Epoch 32/50
# 782/782 [==============================] - 21s 26ms/step - loss: 1.6173 - accuracy: 0.5763 - val_loss: 1.6380 - val_accuracy: 0.5778
# Epoch 33/50
# 782/782 [==============================] - 21s 26ms/step - loss: 1.5964 - accuracy: 0.5803 - val_loss: 1.6852 - val_accuracy: 0.5584
# Epoch 34/50
# 782/782 [==============================] - 21s 26ms/step - loss: 1.5725 - accuracy: 0.5846 - val_loss: 1.6040 - val_accuracy: 0.5765
# Epoch 35/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.5517 - accuracy: 0.5890 - val_loss: 1.5765 - val_accuracy: 0.5828
# Epoch 36/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.5393 - accuracy: 0.5908 - val_loss: 1.6253 - val_accuracy: 0.5808
# Epoch 37/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.5093 - accuracy: 0.6003 - val_loss: 1.5473 - val_accuracy: 0.5975
# Epoch 38/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.4983 - accuracy: 0.6022 - val_loss: 1.5686 - val_accuracy: 0.5920
# Epoch 39/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.4718 - accuracy: 0.6086 - val_loss: 1.6015 - val_accuracy: 0.5859
# Epoch 40/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.4586 - accuracy: 0.6148 - val_loss: 1.6082 - val_accuracy: 0.5856
# Epoch 41/50
# 782/782 [==============================] - 21s 26ms/step - loss: 1.4410 - accuracy: 0.6186 - val_loss: 1.5342 - val_accuracy: 0.6011
# Epoch 42/50
# 782/782 [==============================] - 21s 26ms/step - loss: 1.4198 - accuracy: 0.6229 - val_loss: 1.6456 - val_accuracy: 0.5767
# Epoch 43/50
# 782/782 [==============================] - 21s 26ms/step - loss: 1.4039 - accuracy: 0.6273 - val_loss: 1.5667 - val_accuracy: 0.5906
# Epoch 44/50
# 782/782 [==============================] - 21s 26ms/step - loss: 1.3901 - accuracy: 0.6308 - val_loss: 1.4926 - val_accuracy: 0.6060
# Epoch 45/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.3781 - accuracy: 0.6328 - val_loss: 1.6785 - val_accuracy: 0.5726
# Epoch 46/50
# 782/782 [==============================] - 21s 26ms/step - loss: 1.3544 - accuracy: 0.6380 - val_loss: 1.4945 - val_accuracy: 0.6106
# Epoch 47/50
# 782/782 [==============================] - 21s 26ms/step - loss: 1.3480 - accuracy: 0.6423 - val_loss: 1.6004 - val_accuracy: 0.5858
# Epoch 48/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.3361 - accuracy: 0.6408 - val_loss: 1.5225 - val_accuracy: 0.6007
# Epoch 49/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.3207 - accuracy: 0.6464 - val_loss: 1.5565 - val_accuracy: 0.5981
# Epoch 50/50
# 782/782 [==============================] - 20s 26ms/step - loss: 1.3053 - accuracy: 0.6515 - val_loss: 1.5093 - val_accuracy: 0.6046

# %% [markdown]
# Проверка точности предсказания

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
# Out:
# 313/313 [==============================] - 2s 5ms/step - loss: 1.5093 - accuracy: 0.6046

# %% [markdown]
# Графики

# %%
plt.plot(hist.history['accuracy'])
plt.plot(hist.history['val_accuracy'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# %%
plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
print(plt.show())
# Out:
# None
